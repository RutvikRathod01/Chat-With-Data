# %%
! pip install unstructured openpyxl
# Out:
# Requirement already satisfied: unstructured in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (0.15.13)
# Requirement already satisfied: openpyxl in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: python-magic in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: emoji in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (2.14.0)
# Requirement already satisfied: psutil in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (6.0.0)
# Requirement already satisfied: nltk in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: typing-extensions in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: requests in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: dataclasses-json in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: chardet in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: tqdm in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: backoff in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: unstructured-client in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (0.26.0)
# Requirement already satisfied: python-oxmsg in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (0.0.1)
# Requirement already satisfied: filetype in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: beautifulsoup4 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: wrapt in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: rapidfuzz in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (3.10.0)
# Requirement already satisfied: langdetect in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (5.3.0)
# Requirement already satisfied: numpy<2 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: python-iso639 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (2024.4.27)
# Requirement already satisfied: tabulate in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: et-xmlfile in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: soupsieve>1.2 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from dataclasses-json->unstructured) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from nltk->unstructured) (2024.9.11)
# Requirement already satisfied: joblib in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: olefile in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: pypdf>=4.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (5.0.1)
# Requirement already satisfied: cryptography>=3.1 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (43.0.1)
# Requirement already satisfied: httpx>=0.27.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: cffi>=1.12 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: sniffio in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.5)
# Requirement already satisfied: anyio in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.6.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.9.0->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.9.0->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)

# %%
from langchain_community.document_loaders import UnstructuredExcelLoader
from langchain.schema import Document 

# Load Excel data
excel_loader = UnstructuredExcelLoader(
    file_path = "../data/Rutvik Rathod ATA-KPA (1).xlsx",
)
excel_docs = excel_loader.load()

# %%
# Load custom input text (as a document)
custom_text = ''''Name: Alex Johnson
Title: Computer Engineer
Location: San Francisco, CA
Experience: 5 years
Skills:
 
Programming Languages: Python, Java, C++, JavaScript
Web Development: HTML, CSS, React, Node.js
Databases: MySQL, PostgreSQL, MongoDB
Version Control: Git, GitHub, GitLab
Operating Systems: Linux, Windows
Cloud Services: AWS, Google Cloud Platform
DevOps Tools: Docker, Kubernetes, Jenkins
Machine Learning: TensorFlow, PyTorch
Cybersecurity: Network Security, Encryption, Fi`rewalls
Education:

B.S. in Computer Engineering, Stanford University
Graduated: 2019
GPA: 3.8/4.0'''
custom_doc = [Document(page_content=custom_text)]

# %%
# Combine Excel and custom input text documents
combined_docs = excel_docs + custom_doc

# %%
from dotenv import load_dotenv

load_dotenv("../.env")
# Out:
# True

# %%
import os

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama3-8b-8192")

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(combined_docs)

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2",
    multi_process=True,
    model_kwargs={"device": "cuda"},
    encode_kwargs={"normalize_embeddings": True},
    )
# Out:
# /workspace/gradio-demo/tmpvenv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(documents=splits, embedding=embedding_model)

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 20})

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

system_prompt = (
    """"You are an helpful assistant for question-answering tasks.\n

    Please read the context and question below and provide an answer to the question. and also provide an explanation for your answer.\n
    
    Context:\n {context}?\n
    """
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)


question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
results = rag_chain.invoke({"input": "What is the purpose of the document?"})
# Out:
# Number of requested results 20 is greater than number of elements in index 11, updating n_results = 11

# %%
print(results['answer'])
# Out:
# The purpose of the document appears to be a performance evaluation or a self-assessment report for a computer engineer, Alex Johnson. The document outlines various Key Performance Areas (KPAs) and provides a breakdown of the tasks and projects undertaken by Alex during a specific period.
#
# The document also includes comments and feedback from Alex's supervisor (PTA) and Alex's own reflections on his performance, skills, and core values. The purpose of this document may be to:
#
# 1. Evaluate Alex's performance and provide feedback for improvement.
# 2. Identify areas of strength and areas for development.
# 3. Set goals and objectives for future projects and tasks.
# 4. Demonstrate Alex's skills, experience, and qualifications to potential clients or employers.
# 5. Serve as a reference or portfolio for future job applications.
#
# Overall, the document provides a comprehensive overview of Alex's work, skills, and values, and serves as a tool for personal and professional growth.

# %%
results = rag_chain.invoke({"input": "In which univercity did Alex Johnson graduate?"})
# Out:
# Number of requested results 20 is greater than number of elements in index 11, updating n_results = 11

# %%
print(results['answer'])
# Out:
# According to the given context, Alex Johnson graduated from Stanford University with a Bachelor of Science (B.S.) in Computer Engineering in 2019 with a GPA of 3.8/4.0.
